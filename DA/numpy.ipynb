# %% [markdown]
# ## Intro to Numpy

# %%
import numpy as np

# %%
marks = [92,20,78]

arr = np.array(marks)

arr.max()
# Out:
# np.int64(92)

# %%
z = np.ones(5)

z
# Out:
# array([1., 1., 1., 1., 1.])

# %%
arr_3d = np.array([
    [[1, 2], [3, 4],[22,33]],
    [[5, 6], [7, 8],[44,55]]
])
arr_3d.size
# Out:
# 12
